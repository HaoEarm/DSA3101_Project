# %%
from google_play_scraper import app, Sort, reviews_all
from app_store_scraper import AppStore
import pandas as pd
import numpy as np
import json, os, uuid

# %%
g_reviews = reviews_all(
        "sg.trust",
        sleep_milliseconds=0, # defaults to 0
        lang='en', # defaults to 'en'
        country='sg', # defaults to 'sg'
        sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    )
len(g_reviews)
# Out:
# 398

# %%
g_df = pd.DataFrame(np.array(g_reviews),columns=['review'])
g_df2 = g_df.join(pd.DataFrame(g_df.pop('review').tolist()))

g_df2.drop(columns={'userImage', 'reviewCreatedVersion'},inplace = True)
g_df2.rename(columns= {'score': 'rating','userName': 'user_name', 'reviewId': 'review_id', 'content': 'review_description', 'at': 'review_date', 'replyContent': 'developer_response', 'repliedAt': 'developer_response_date', 'thumbsUpCount': 'thumbs_up'},inplace = True)
g_df2.insert(loc=0, column='source', value='Google Play')
g_df2.insert(loc=3, column='review_title', value=None)
g_df2['laguage_code'] = 'en'
g_df2['country_code'] = 'sg'
g_df2
# Out:
#           source                             review_id           user_name  \
# 0    Google Play  c4039844-5671-480d-bd8d-696d14bd91c5          Alvin Ding
# 1    Google Play  f24ed3bc-6425-4f62-9fb0-ecea39843a33           Subash .N
# 2    Google Play  e32dc5ac-c243-4482-a5e5-145f4fe0b6f4       MAHESH RAJA R
# 3    Google Play  beb52e5f-bd6b-4512-801d-817ad55be08c              Karthi
# 4    Google Play  1d308402-08cb-443c-bbf6-511a0589a8d6  S Kiruthika Selvam
# ..           ...                                   ...                 ...
# 393  Google Play  5d3590ec-99ad-4460-86e4-9f40daaed2ce                   Z
# 394  Google Play  67545aaa-bddc-4f6b-9f78-e0626fed6b5e      Cheryl8 Rivero
# 395  Google Play  768cd697-cc6d-4c9a-82a2-d49b357b4460            Seng Hin
# 396  Google Play  5efd7f29-7dc2-4fc7-943f-61d72deb83ff        Cheah Kumlin
# 397  Google Play  14c5c6d0-2db9-429b-bf47-b21196a75bd9    Charles Jennings
#
#     review_title                                 review_description  rating  \
# 0           None  Do not dictate risk app or not, you can warm b...       1
# 1           None  Trust Bank SG app is good to use banking exper...       5
# 2           None  Trust Bank sg is best application is very easy...       5
# 3           None  Trust bank SG is very good app and easy to tra...       5
# 4           None  trust Bank sg is very useful to poor people th...       5
# ..           ...                                                ...     ...
# 393         None  Zero trust in this bank, anyhow lock your acco...       1
# 394         None                                               Good       5
# 395         None                                        Easy to use       5
# 396         None                                     Easy to follow       4
# 397         None                                Ez to use, great UI       5
#
#      thumbs_up         review_date  \
# 0            0 2024-03-12 23:47:21
# 1            0 2024-03-11 14:28:26
# 2            0 2024-03-11 14:16:09
# 3            0 2024-03-11 14:14:07
# 4            0 2024-03-11 13:42:48
# ..         ...                 ...
# 393          0 2023-09-18 06:15:23
# 394          0 2023-09-18 05:15:34
# 395          0 2023-09-17 04:22:31
# 396          0 2023-09-15 03:57:30
# 397          0 2023-09-14 14:16:17
#
#                                     developer_response  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 393  Hi Z, we are extremely sorry to hear you are f...
# 394  Hi Cheryl8 Rivero, we are glad that you like o...
# 395  Hey Seng Hin, thank you for your amazing feedb...
# 396  Hey Cheah Kumlin, we are so glad to hear that!...
# 397  Hi Charles Jennings, we are glad that you like...
#
#     developer_response_date appVersion laguage_code country_code
# 0                       NaT     1.25.1           en           sg
# 1                       NaT     1.25.1           en           sg
# 2                       NaT     1.25.1           en           sg
# 3                       NaT     1.25.1           en           sg
# 4                       NaT     1.25.1           en           sg
# ..                      ...        ...          ...          ...
# 393     2023-09-18 07:15:51     1.17.2           en           sg
# 394     2023-09-18 07:17:09      1.8.1           en           sg
# 395     2023-09-18 07:21:18     1.17.2           en           sg
# 396     2023-09-15 07:19:20     1.17.2           en           sg
# 397     2023-09-15 07:18:19       None           en           sg
#
# [398 rows x 13 columns]
