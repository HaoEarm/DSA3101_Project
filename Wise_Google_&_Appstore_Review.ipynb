# %%
from google_play_scraper import app, Sort, reviews_all
from app_store_scraper import AppStore
import pandas as pd
import numpy as np
import json, os, uuid

# %%
g_reviews = reviews_all(
        "com.transferwise.android",
        sleep_milliseconds=0, # defaults to 0
        lang='en', # defaults to 'en'
        country='sg', # defaults to 'sg'
        sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    )
len(g_reviews)
# Out:
# 398

# %%
g_df = pd.DataFrame(np.array(g_reviews),columns=['review'])
g_df2 = g_df.join(pd.DataFrame(g_df.pop('review').tolist()))

g_df2.drop(columns={'userImage', 'reviewCreatedVersion'},inplace = True)
g_df2.rename(columns= {'score': 'rating','userName': 'user_name', 'reviewId': 'review_id', 'content': 'review_description', 'at': 'review_date', 'replyContent': 'developer_response', 'repliedAt': 'developer_response_date', 'thumbsUpCount': 'thumbs_up'},inplace = True)
g_df2.insert(loc=0, column='source', value='Google Play')
g_df2.insert(loc=3, column='review_title', value=None)
g_df2['laguage_code'] = 'en'
g_df2['country_code'] = 'sg'
g_df2
# Out:
#           source                             review_id        user_name  \
# 0    Google Play  fcc75d2c-e170-40bb-a275-9dfa310cf1dc        Raj Chana
# 1    Google Play  2baabfae-3e51-41d8-bc65-c77b0fc698c4         DannyMah
# 2    Google Play  7539bab8-3200-4bd4-b913-037e6963871a     Donald Jones
# 3    Google Play  d0333522-03a4-4539-8cbd-5e299b7828ee       Jason Watt
# 4    Google Play  3739b607-d03c-4fa6-bfcf-eb51709bd2a9       Tina Brown
# ..           ...                                   ...              ...
# 393  Google Play  4815b0b9-98cf-4049-9f51-2c34e1e08969  Tihomir Nenchev
# 394  Google Play  0055a365-d200-49c8-8019-6d4cfc261a54      Anjay Jacob
# 395  Google Play  173fbf8e-b2e7-4602-a92c-9ba1e163aab2   Rkkona Aktarrk
# 396  Google Play  5750db2c-a0fa-482f-83d0-ee317e398595   Chris Morrison
# 397  Google Play  86743d35-4e0d-4dbd-aea6-1883497c7237   Colin Carrigan
#
#     review_title                                 review_description  rating  \
# 0           None  brilliant bank, brilliant app. Easy as pie to ...       5
# 1           None  thanks for the great app. it makes our family ...       5
# 2           None                                 Very user friendly       5
# 3           None                                           Best App       5
# 4           None                             exceptionally reliable       5
# ..           ...                                                ...     ...
# 393         None  8 years with the app, never thought for anothe...       5
# 394         None  Worst customer service ever.!!! They force you...       1
# 395         None                                               robi       5
# 396         None                                        Brilliant!!       5
# 397         None                Very quick transfer and low charges       5
#
#      thumbs_up         review_date developer_response developer_response_date  \
# 0            0 2024-03-13 09:06:06               None                     NaT
# 1            0 2024-03-13 08:13:49               None                     NaT
# 2            0 2024-03-13 07:53:02               None                     NaT
# 3            0 2024-03-13 07:34:58               None                     NaT
# 4            0 2024-03-13 07:01:20               None                     NaT
# ..         ...                 ...                ...                     ...
# 393          0 2024-03-07 18:10:54               None                     NaT
# 394          1 2024-03-07 17:53:58               None                     NaT
# 395          0 2024-03-07 17:46:48               None                     NaT
# 396          0 2024-03-07 17:42:11               None                     NaT
# 397          0 2024-03-07 17:20:36               None                     NaT
#
#     appVersion laguage_code country_code
# 0       8.50.2           en           sg
# 1       8.51.0           en           sg
# 2       8.29.1           en           sg
# 3       8.51.0           en           sg
# 4       8.51.0           en           sg
# ..         ...          ...          ...
# 393     8.50.2           en           sg
# 394     8.47.1           en           sg
# 395     8.49.0           en           sg
# 396     8.49.0           en           sg
# 397     8.47.1           en           sg
#
# [398 rows x 13 columns]

# %%
a_reviews = AppStore('sg', 'wise', '612261027')
a_reviews.review()

# %%
a_df = pd.DataFrame(np.array(a_reviews.reviews),columns=['review'])
a_df2 = a_df.join(pd.DataFrame(a_df.pop('review').tolist()))

a_df2.drop(columns={'isEdited'},inplace = True)
a_df2.insert(loc=0, column='source', value='App Store')
a_df2['developer_response_date'] = None
a_df2['thumbs_up'] = None
a_df2['laguage_code'] = 'en'
a_df2['country_code'] = 'sg'
a_df2.insert(loc=1, column='review_id', value=[uuid.uuid4() for _ in range(len(a_df2.index))])
a_df2.rename(columns= {'review': 'review_description','userName': 'user_name', 'date': 'review_date','title': 'review_title', 'developerResponse': 'developer_response'},inplace = True)
a_df2 = a_df2.where(pd.notnull(a_df2), None)
a_df2
# Out:
#         source                             review_id         review_date  \
# 0    App Store  3e2b7f9a-84f2-4555-9282-6a8473c46acb 2019-04-12 13:56:59
# 1    App Store  2c3cb9f3-6bca-41e6-b147-7b017253165b 2023-05-06 15:59:03
# 2    App Store  e0e5d681-8a8f-4bf0-97ba-1b2dcd047906 2022-06-30 13:24:37
# 3    App Store  4243440c-8fed-4f08-97e5-2e96d2c2905e 2021-01-05 09:17:18
# 4    App Store  6fcdd4cd-e49e-4e78-b0e7-5b4ab3da3980 2024-02-05 06:12:16
# ..         ...                                   ...                 ...
# 676  App Store  8b900428-3830-4c39-a172-723a4518cb78 2020-05-10 18:02:08
# 677  App Store  9f43e5c2-49e4-4b18-82fd-859f886d3822 2019-06-22 03:39:06
# 678  App Store  c4e2b6d3-cc8a-41a7-a523-e3fb49f52bf3 2020-01-24 05:30:12
# 679  App Store  2b5ab246-0eca-4809-8364-3170b35050d0 2019-12-13 22:19:48
# 680  App Store  6d25279e-4725-4d2b-906a-f1993be4096e 2019-05-27 07:30:09
#
#                                     review_description  rating  \
# 0    Switched from PayPal business account to Trans...       5
# 1    I got a transferwise credit card when I had a ...       5
# 2    When I started to used wise previously since 2...       1
# 3    I’ve been using the App now for a couple of ye...       5
# 4    Having used Wise since 2020 (when it was Trans...       1
# ..                                                 ...     ...
# 676  I start to use transferwise after watching an ...       4
# 677  04/04/19 Made my fist high value transaction -...       5
# 678          Very good but QR code will make it easier       4
# 679  Using Apple Pay to transfer $10SGD to my own T...       1
# 680  Sent US7.44 to a supplier account in Singapore...       1
#
#                user_name                                       review_title  \
# 0                 Jes C.   Best there is... way better than PayPal or Banks
# 1         bassicinstinct                          easy to use & great rates
# 2                 Lia512                         Now the system is worse!!!
# 3         MikeMorrison79              Everyone should have and use this App
# 4            KeithHitman                         Use Wise at your own risk!
# ..                   ...                                                ...
# 676           ThomasGOWM                             Almost perfect System!
# 677           Sumit_2002                                  Yup , truly works
# 678   Michelle G Gabriel      Allow clients to scan QR code for easy paynow
# 679             Arabouji              Expensive 3rd Party Bank Transfer Fee
# 680  Transferred-Really?  Unsatisfactory Transfer (Send US7.44 Received ...
#
#     developer_response developer_response_date thumbs_up laguage_code  \
# 0                 None                    None      None           en
# 1                 None                    None      None           en
# 2                 None                    None      None           en
# 3                 None                    None      None           en
# 4                 None                    None      None           en
# ..                 ...                     ...       ...          ...
# 676               None                    None      None           en
# 677               None                    None      None           en
# 678               None                    None      None           en
# 679               None                    None      None           en
# 680               None                    None      None           en
#
#     country_code
# 0             sg
# 1             sg
# 2             sg
# 3             sg
# 4             sg
# ..           ...
# 676           sg
# 677           sg
# 678           sg
# 679           sg
# 680           sg
#
# [681 rows x 12 columns]

# %%
result = pd.concat([g_df2,a_df2])
result
# Out:
#           source                             review_id            user_name  \
# 0    Google Play  fcc75d2c-e170-40bb-a275-9dfa310cf1dc            Raj Chana
# 1    Google Play  2baabfae-3e51-41d8-bc65-c77b0fc698c4             DannyMah
# 2    Google Play  7539bab8-3200-4bd4-b913-037e6963871a         Donald Jones
# 3    Google Play  d0333522-03a4-4539-8cbd-5e299b7828ee           Jason Watt
# 4    Google Play  3739b607-d03c-4fa6-bfcf-eb51709bd2a9           Tina Brown
# ..           ...                                   ...                  ...
# 676    App Store  8b900428-3830-4c39-a172-723a4518cb78           ThomasGOWM
# 677    App Store  9f43e5c2-49e4-4b18-82fd-859f886d3822           Sumit_2002
# 678    App Store  c4e2b6d3-cc8a-41a7-a523-e3fb49f52bf3   Michelle G Gabriel
# 679    App Store  2b5ab246-0eca-4809-8364-3170b35050d0             Arabouji
# 680    App Store  6d25279e-4725-4d2b-906a-f1993be4096e  Transferred-Really?
#
#                                           review_title  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 676                             Almost perfect System!
# 677                                  Yup , truly works
# 678      Allow clients to scan QR code for easy paynow
# 679              Expensive 3rd Party Bank Transfer Fee
# 680  Unsatisfactory Transfer (Send US7.44 Received ...
#
#                                     review_description  rating thumbs_up  \
# 0    brilliant bank, brilliant app. Easy as pie to ...       5         0
# 1    thanks for the great app. it makes our family ...       5         0
# 2                                   Very user friendly       5         0
# 3                                             Best App       5         0
# 4                               exceptionally reliable       5         0
# ..                                                 ...     ...       ...
# 676  I start to use transferwise after watching an ...       4      None
# 677  04/04/19 Made my fist high value transaction -...       5      None
# 678          Very good but QR code will make it easier       4      None
# 679  Using Apple Pay to transfer $10SGD to my own T...       1      None
# 680  Sent US7.44 to a supplier account in Singapore...       1      None
#
#             review_date developer_response developer_response_date appVersion  \
# 0   2024-03-13 09:06:06               None                     NaT     8.50.2
# 1   2024-03-13 08:13:49               None                     NaT     8.51.0
# 2   2024-03-13 07:53:02               None                     NaT     8.29.1
# 3   2024-03-13 07:34:58               None                     NaT     8.51.0
# 4   2024-03-13 07:01:20               None                     NaT     8.51.0
# ..                  ...                ...                     ...        ...
# 676 2020-05-10 18:02:08               None                     NaT        NaN
# 677 2019-06-22 03:39:06               None                     NaT        NaN
# 678 2020-01-24 05:30:12               None                     NaT        NaN
# 679 2019-12-13 22:19:48               None                     NaT        NaN
# 680 2019-05-27 07:30:09               None                     NaT        NaN
#
#     laguage_code country_code
# 0             en           sg
# 1             en           sg
# 2             en           sg
# 3             en           sg
# 4             en           sg
# ..           ...          ...
# 676           en           sg
# 677           en           sg
# 678           en           sg
# 679           en           sg
# 680           en           sg
#
# [1079 rows x 13 columns]
